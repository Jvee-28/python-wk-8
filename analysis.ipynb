# %% [markdown]
# # Analysis Notebook for CORD-19 Dataset
#
# This notebook explores the CORD-19 metadata.csv dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('metadata.csv')
df.head()
